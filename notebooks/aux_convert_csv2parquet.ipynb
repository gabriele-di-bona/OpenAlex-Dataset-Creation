# %% [markdown]
# # Library

# %%
import os
os.chdir("../") # resets notebook directory to repository root folder (DO ONLY ONCE!)
import polars as pl
import pandas as pd
import pyarrow.parquet as pypq
import textwrap
from pathlib import Path
import time

from tqdm.auto import tqdm
tqdm.pandas()

# %%
import sys
# Add utils directory in the list of directories to look for packages to import
sys.path.insert(0, os.path.join(os.getcwd(),'utils'))
from read_parquet import *
# Out:
# Using PyArrow strings!

# %% [markdown]
# ## Functions to convert

# %%
def convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = None, separator=',', compression='brotli', do_peek = True, do_print = True):
    os.makedirs(os.path.dirname(parquet_file_path), exist_ok=True)
    df = pl.read_csv(csv_file_path, separator=separator, infer_schema_length=1000)
    if sort_by is not None:
        # sort first by first column name in title, than second if equal, etc.
        df = df.sort(sort_by, descending = True)
    df.write_parquet(parquet_file_path, compression=compression)
    if do_print:
        print(f"Successfully converted {csv_file_path} to {parquet_file_path}.")
    if do_peek:
        if do_print:
            print("Here's a peek.")
        peek_parquet(parquet_file_path)

# %% [markdown]
# # Conversion

# %% [markdown]
# ## Authors

# %%
csv_file_path = "data/authors/authors.csv"
parquet_file_path = "data/authors/authors.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = ["h_index", "cited_by_count", "works_count"], separator = ',')
# Out:
# Successfully converted data/authors/authors.csv to data/authors/authors.parquet.
# Here's a peek.
# Name: 'authors'
# Path: 'data/authors/authors.parquet'
# Files: 1
# Rows: 107,541,376
# Schema:
#     id: large_string
#     display_name: large_string
#     orcid: large_string
#     works_count: int64
#     h_index: int64
#     cited_by_count: int64
#     topics: large_string
#     affiliations: large_string
#     works_count_by_year: large_string
#     cited_by_count_by_year: large_string
# 5 random rows:
#             id       display_name                orcid  works_count  h_index  \
# 0  A5100376569     Zhong Lin Wang  0000-0002-5530-0380         3868      318
# 1  A5083991449  Walter C. Willett  0000-0003-1458-7597         2715      312
# 2  A5075296559      Guido Kroemer  0000-0002-9334-4405         2303      281
# 3  A5109160404    Michaël Grätzel                              1896      280
# 4  A5057810294  Ronald C. Kessler  0000-0003-4831-2305         1649      276
#
#    cited_by_count                                             topics  \
# 0          458687  T10338_2059;T10660_1274;T11230_475;T10914_432;...
# 1          398222  T10866_1195;T10010_438;T12267_402;T12103_356;T...
# 2          364156  T10587_392;T10294_332;T10158_318;T10580_317;T1...
# 3          391876  T10024_762;T10078_670;T10247_519;T10321_390;T1...
# 4          350337  T10272_472;T10182_357;T10376_239;T10242_231;T1...
#
#                                         affiliations  \
# 0                                       I63966007_US
# 1  I1283280774_US;I136199984_US;I2801851002_US;I4...
# 2  I1294671590_FR;I154526488_FR;I185839726_FR;I20...
# 3  I105140100_ES_2012_2010;I107639228_US_1975_197...
# 4          I136199984_US;I2801851002_US;I36258959_US
#
#                                  works_count_by_year  \
# 0  1_1979;1_1984;1_1986;8_1987;5_1988;11_1989;8_1...
# 1  1_1976;1_1977;3_1980;7_1981;1_1982;5_1983;10_1...
# 2  1_1979;1_1982;1_1986;3_1987;8_1988;5_1989;11_1...
# 3  6_1973;3_1974;6_1975;8_1976;6_1977;10_1978;15_...
# 4  1_1963;2_1970;1_1975;2_1976;4_1977;2_1978;9_19...
#
#                               cited_by_count_by_year
# 0  5_1984;9_1986;240_1987;98_1988;264_1989;116_19...
# 1  21_1977;78_1980;356_1981;6_1982;833_1983;1959_...
# 2  4_1979;50_1987;78_1988;340_1989;358_1990;369_1...
# 3  194_1973;466_1974;266_1975;123_1976;92_1977;86...
# 4  6_1970;8_1975;181_1976;415_1977;762_1978;983_1...

# %% [markdown]
# ## Institutions

# %%
csv_file_path = "data/institutions/institutions.csv"
parquet_file_path = "data/institutions/institutions.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = "works_count", separator = ';')
# Out:
# Successfully converted data/institutions/institutions.csv to data/institutions/institutions.parquet.
# Here's a peek.
# Name: 'institutions'
# Path: 'data/institutions/institutions.parquet'
# Files: 1
# Rows: 120,658
# Schema:
#     id: large_string
#     ror_id: large_string
#     display_name: large_string
#     type: large_string
#     country_code: large_string
#     country: large_string
#     city: large_string
#     coord: large_string
#     works_count: int64
# 5 random rows:
#            id     ror_id                             display_name        type  \
# 0  I100005738  047rhhm47                 Brigham Young University   education
# 1  I100019715  04m1j1t24      Australian Institute of Criminology  government
# 2  I100051649  00apdsa62  Privolzhsky Research Medical University   education
# 3  I100063501  01qz7fr76       Brighton and Sussex Medical School   education
# 4  I100066346  04vnq7t77                  University of Stuttgart   education
#
#   country_code         country             city  \
# 0           US   United States            Provo
# 1           AU       Australia         Canberra
# 2           RU          Russia  Nizhny Novgorod
# 3           GB  United Kingdom         Brighton
# 4           DE         Germany        Stuttgart
#
#                                     coord  works_count
# 0   40.23384094238281_-111.65853118896484            0
# 1  -35.314842224121094_149.13067626953125            0
# 2    56.32921600341797_44.009483337402344            0
# 3   50.8650016784668_-0.08500000089406967            0
# 4    48.782318115234375_9.177020072937012            0

# %% [markdown]
# ## Sources

# %%
csv_file_path = "data/sources/sources.csv"
parquet_file_path = "data/sources/sources.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = "works_count", separator = ';')
# Out:
# Successfully converted data/sources/sources.csv to data/sources/sources.parquet.
# Here's a peek.
# Name: 'sources'
# Path: 'data/sources/sources.parquet'
# Files: 1
# Rows: 255,250
# Schema:
#     id: large_string
#     display_name: large_string
#     issn: large_string
#     type: large_string
#     publisher: large_string
#     host_organization: large_string
#     country_code: large_string
#     apc_usd: large_string
#     works_count: int64
#     cited_by_count: int64
#     h_index: int64
#     i10_index: int64
#     2yr_h_index: large_string
#     2yr_i10_index: large_string
#     2yr_mean_citedness: double
#     is_oa: large_string
#     is_in_doaj: large_string
#     is_core: large_string
#     is_indexed_in_scopus: large_string
# 5 random rows:
#             id                                       display_name issn  \
# 0  S7407052672                                               NIFS
# 1  S4306400562  Zenodo (CERN European Organization for Nuclear...
# 2  S4306525036                                             PubMed
# 3  S4377196541                Internet Archive (Internet Archive)
# 4  S4306400572          OPAL (Open@LaTrobe) (La Trobe University)
#
#          type publisher                                host_organization  \
# 0  repository                      National Institute for Fusion Science
# 1  repository            CERN European Organization for Nuclear Research
# 2  repository
# 3  repository
# 4  repository                                        La Trobe University
#
#   country_code apc_usd  works_count  cited_by_count  h_index  i10_index  \
# 0                          28552162               0        0          0
# 1                          10147031         1250513      221      21500
# 2           US              7891251        46362456      939     965613
# 3                           7808691          785301      305      11526
# 4                           6743036          591312      197       8617
#
#   2yr_h_index 2yr_i10_index  2yr_mean_citedness is_oa is_in_doaj is_core  \
# 0                                      0.000000     F          F       F
# 1                                      0.063284     T          F       F
# 2                                      1.275151     F          F       F
# 3                                      0.018623     F          F       F
# 4                                      0.034260     F          F       F
#
#   is_indexed_in_scopus
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Publishers

# %%
csv_file_path = "data/publishers/publishers.csv"
parquet_file_path = "data/publishers/publishers.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = "works_count", separator = ';')
# Out:
# Successfully converted data/publishers/publishers.csv to data/publishers/publishers.parquet.
# Here's a peek.
# Name: 'publishers'
# Path: 'data/publishers/publishers.parquet'
# Files: 1
# Rows: 10,703
# Schema:
#     id: large_string
#     display_name: large_string
#     parent_publisher: large_string
#     works_count: int64
#     cited_by_count: int64
# 5 random rows:
#             id                     display_name parent_publisher  works_count  \
# 0  P4310320990                      Elsevier BV                      23598446
# 1  P4310320595                            Wiley                      10838394
# 2  P4310319900  Springer Science+Business Media      P4310319965      8123358
# 3  P4310311648          Oxford University Press      P4310311647      4797691
# 4  P4310320547                 Taylor & Francis                       4793689
#
#    cited_by_count
# 0       622938130
# 1       242850675
# 2       153833249
# 3       106429269
# 4        76694442

# %% [markdown]
# ## Funders

# %%
csv_file_path = "data/funders/funders.csv"
parquet_file_path = "data/funders/funders.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = ['grants_count','works_count'], separator = ';')
# Out:
# Successfully converted data/funders/funders.csv to data/funders/funders.parquet.
# Here's a peek.
# Name: 'funders'
# Path: 'data/funders/funders.parquet'
# Files: 1
# Rows: 32,437
# Schema:
#     id: large_string
#     display_name: large_string
#     country_code: large_string
#     grants_count: large_string
#     works_count: int64
# 5 random rows:
#             id                                  display_name country_code  \
# 0  F4320321001  National Natural Science Foundation of China           CN
# 1  F4320306076                   National Science Foundation           US
# 2  F4320332161                 National Institutes of Health           US
# 3  F4320320879               Deutsche Forschungsgemeinschaft           DE
# 4  F4320320300                           European Commission
#
#   grants_count  works_count
# 0                   3567548
# 1                   1483056
# 2                   1434393
# 3                    602570
# 4                    585308

# %% [markdown]
# ## Awards

# %%
csv_file_path = "data/awards/awards.csv"
parquet_file_path = "data/awards/awards.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = ['start_date','end_date'], separator = ';')
# Out:
# Successfully converted data/awards/awards.csv to data/awards/awards.parquet.
# Here's a peek.
# Name: 'awards'
# Path: 'data/awards/awards.parquet'
# Files: 1
# Rows: 11,746,894
# Schema:
#     id: large_string
#     display_name: large_string
#     description: large_string
#     funder_id: large_string
#     funding_type: large_string
#     funded_outputs_count: int64
#     funded_outputs: large_string
#     start_date: large_string
#     end_date: large_string
#     doi: large_string
# 5 random rows:
#             id                                       display_name  \
# 0  G4053403331  Exploring the architecture of interfaces and b...
# 1  G1977985897  Predicting Mosquito-Borne Disease Risks In Sco...
# 2   G855121204  Reflections on DNA - how do topoisomerases dis...
# 3  G6183439496  Photography and Seafaring: Making Visible Mart...
# 4  G6934949649  The history, significance and interpretative v...
#
#                                          description    funder_id  \
# 0  Despite the significant architectural and plan...  F4320334609
# 1  Food Security, Mosquito. Livestock. Trypanosom...  F4320334629
# 2  DNA is a long double-helical molecule that bec...  F4320334629
# 3  This project aims to produce new visual interp...  F4320334609
# 4  In 2018, National Museums Northern Ireland (NM...  F4320334609
#
#   funding_type  funded_outputs_count funded_outputs  start_date    end_date  \
# 0  studentship                     0                 2031-03-30  2031-03-30
# 1  studentship                     0                 2028-10-06  2028-10-06
# 2  studentship                     0                 2028-10-06  2028-10-06
# 3  studentship                     0                 2028-09-29  2028-11-09
# 4  studentship                     0                 2028-09-29  2028-09-29
#
#   doi
# 0
# 1
# 2
# 3
# 4

# %%
awards_df = read_parquet("data/awards/awards.parquet")
# Out:
# Reading 'awards' from 'data/awards/awards.parquet' using engine='pyarrow'
# Read 11,746,894 rows from 'awards' in 38.09 sec.
# Converting dtypes took 0.07 sec. Size before: 4.89GB, after: 4.89GB
#             id                                       display_name  \
# 0  G4053403331  Exploring the architecture of interfaces and b...
# 1  G1977985897  Predicting Mosquito-Borne Disease Risks In Sco...
# 2   G855121204  Reflections on DNA - how do topoisomerases dis...
#
#                                          description    funder_id  \
# 0  Despite the significant architectural and plan...  F4320334609
# 1  Food Security, Mosquito. Livestock. Trypanosom...  F4320334629
# 2  DNA is a long double-helical molecule that bec...  F4320334629
#
#   funding_type  funded_outputs_count funded_outputs  start_date    end_date  \
# 0  studentship                     0                 2031-03-30  2031-03-30
# 1  studentship                     0                 2028-10-06  2028-10-06
# 2  studentship                     0                 2028-10-06  2028-10-06
#
#   doi
# 0
# 1
# 2

# %%
awards_df.funded_outputs_count.value_counts()
# Out:
# funded_outputs_count
# 0       4982301
# 1       4486971
# 2        937659
# 3        412332
# 4        235924
#          ...
# 319           1
# 733           1
# 676           1
# 399           1
# 3835          1
# Name: count, Length: 464, dtype: int64

# %% [markdown]
# ## Topics

# %%
csv_file_path = "data/topics/topics.csv"
parquet_file_path = "data/topics/topics.parquet"

convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = ["works_count", "cited_by_count", ], separator = ';')
# Out:
# Successfully converted data/topics/topics.csv to data/topics/topics.parquet.
# Here's a peek.
# Name: 'topics'
# Path: 'data/topics/topics.parquet'
# Files: 1
# Rows: 4,516
# Schema:
#     topic_id: large_string
#     display_name: large_string
#     description: large_string
#     keywords: large_string
#     wikipedia: large_string
#     subfield_id: int64
#     subfield_name: large_string
#     field_id: int64
#     field_name: large_string
#     domain_id: int64
#     domain_name: large_string
#     sibling_ids: large_string
#     works_count: int64
#     cited_by_count: int64
# 5 random rows:
#   topic_id                              display_name  \
# 0   T10346      Magnetic confinement fusion research
# 1   T12157         Geochemistry and Geologic Mapping
# 2   T10451  Mycorrhizal Fungi and Plant Interactions
# 3   T13370   Diverse Scientific and Economic Studies
# 4   T14423        Military Technology and Strategies
#
#                                          description  \
# 0  This cluster of papers covers a wide range of ...
# 1  This cluster of papers focuses on the applicat...
# 2  This cluster of papers explores the diverse in...
# 3  This cluster of papers covers topics related t...
# 4  This cluster of papers covers various aspects ...
#
#                                             keywords  \
# 0  Turbulence_Tokamak_Transport_MHD Stability_Edg...
# 1  Machine Learning_Mineral Prospectivity_Remote ...
# 2  Mycorrhizal Fungi_Fungal Diversity_Plant Inter...
# 3  Financial Analysis_Monetary Policy_Asset Prici...
# 4  Air Force_Modernization_Warfare_Unmanned Aeria...
#
#                                            wikipedia  subfield_id  \
# 0       https://en.wikipedia.org/wiki/Plasma_physics         3106
# 1  https://en.wikipedia.org/wiki/Mineral_prospecting         1702
# 2           https://en.wikipedia.org/wiki/Mycorrhiza         1110
# 3                                                NaN         2002
# 4  https://en.wikipedia.org/wiki/Air_force_modern...         2202
#
#                      subfield_name  field_id  \
# 0  Nuclear and High Energy Physics        31
# 1          Artificial Intelligence        17
# 2                    Plant Science        11
# 3       Economics and Econometrics        20
# 4            Aerospace Engineering        22
#
#                              field_name  domain_id        domain_name  \
# 0                 Physics and Astronomy          3  Physical Sciences
# 1                      Computer Science          3  Physical Sciences
# 2  Agricultural and Biological Sciences          1      Life Sciences
# 3   Economics, Econometrics and Finance          2    Social Sciences
# 4                           Engineering          3  Physical Sciences
#
#                                          sibling_ids  works_count  \
# 0  T10025_T10384_T11044_T13458_T10921_T10093_T100...      9270869
# 1  T13674_T12380_T10951_T11010_T13650_T14175_T126...      3952624
# 2  T12253_T11796_T11578_T13422_T11613_T12657_T106...      3202968
# 3  T13547_T12446_T11270_T10471_T14143_T12394_T106...      2968659
# 4  T10944_T12560_T12696_T10069_T13200_T12158_T106...      2202490
#
#    cited_by_count
# 0         2538117
# 1         1640349
# 2         1949520
# 3          239038
# 4           27852

# %%
topics_df = read_parquet("data/topics/topics.parquet")
AI_topics_df = topics_df[topics_df.subfield_name == "Artificial Intelligence"]
AI_topics_df
# Out:
# Reading 'topics' from 'data/topics/topics.parquet' using engine='pyarrow'
# Read 4,516 rows from 'topics' in 0.07 sec.
# Converting dtypes took 0.00 sec. Size before: 0.01GB, after: 0.01GB
#   topic_id                              display_name  \
# 0   T10346      Magnetic confinement fusion research
# 1   T12157         Geochemistry and Geologic Mapping
# 2   T10451  Mycorrhizal Fungi and Plant Interactions
#
#                                          description  \
# 0  This cluster of papers covers a wide range of ...
# 1  This cluster of papers focuses on the applicat...
# 2  This cluster of papers explores the diverse in...
#
#                                             keywords  \
# 0  Turbulence_Tokamak_Transport_MHD Stability_Edg...
# 1  Machine Learning_Mineral Prospectivity_Remote ...
# 2  Mycorrhizal Fungi_Fungal Diversity_Plant Inter...
#
#                                            wikipedia  subfield_id  \
# 0       https://en.wikipedia.org/wiki/Plasma_physics         3106
# 1  https://en.wikipedia.org/wiki/Mineral_prospecting         1702
# 2           https://en.wikipedia.org/wiki/Mycorrhiza         1110
#
#                      subfield_name  field_id  \
# 0  Nuclear and High Energy Physics        31
# 1          Artificial Intelligence        17
# 2                    Plant Science        11
#
#                              field_name  domain_id        domain_name  \
# 0                 Physics and Astronomy          3  Physical Sciences
# 1                      Computer Science          3  Physical Sciences
# 2  Agricultural and Biological Sciences          1      Life Sciences
#
#                                          sibling_ids  works_count  \
# 0  T10025_T10384_T11044_T13458_T10921_T10093_T100...      9270869
# 1  T13674_T12380_T10951_T11010_T13650_T14175_T126...      3952624
# 2  T12253_T11796_T11578_T13422_T11613_T12657_T106...      3202968
#
#    cited_by_count
# 0         2538117
# 1         1640349
# 2         1949520
#      topic_id                                   display_name  \
# 1      T12157              Geochemistry and Geologic Mapping
# 37     T13650  Computational Physics and Python Applications
# 88     T10181         Natural Language Processing Techniques
# 121    T10320               Neural Networks and Applications
# 151    T13398                           Data Analysis with R
# ...       ...                                            ...
# 4096   T13935      Mathematical Control Systems and Analysis
# 4163   T14413        Advanced Technologies in Various Fields
# 4335   T14175      Intuitionistic Fuzzy Systems Applications
# 4444   T13567                 AI and Multimedia in Education
# 4484   T13514          Experience-Based Knowledge Management
#
#                                             description  \
# 1     This cluster of papers focuses on the applicat...
# 37    This cluster of papers covers a wide range of ...
# 88    This cluster of papers focuses on statistical ...
# 121   This cluster of papers covers a wide range of ...
# 151   This cluster of papers focuses on statistical ...
# ...                                                 ...
# 4096  This cluster of papers focuses on the applicat...
# 4163  This cluster of papers focuses on the developm...
# 4335  This cluster of papers focuses on enhancing e-...
# 4444  This cluster of papers focuses on the optimiza...
# 4484  This cluster of papers focuses on experience-b...
#
#                                                keywords  \
# 1     Machine Learning_Mineral Prospectivity_Remote ...
# 37    Python_Scientific Computing_Statistical Modeli...
# 88    Statistical Machine Translation_Neural Machine...
# 121   Neural Networks_Self-Organizing Maps_Backpropa...
# 151   R language_statistical analysis_data visualiza...
# ...                                                 ...
# 4096  Fuzzy Computing_Intelligent Systems_Soft Compu...
# 4163  Graph Embedding_Visual Question Answering_Sema...
# 4335  Intelligent Agent_E-Learning_InterCriteria Ana...
# 4444  Big Data Scheduling_Fractal Encoding_Visual Tr...
# 4484  Decisional DNA_Set of Experience Knowledge Str...
#
#                                               wikipedia  subfield_id  \
# 1     https://en.wikipedia.org/wiki/Mineral_prospecting         1702
# 37    https://en.wikipedia.org/wiki/Python_(programm...         1702
# 88    https://en.wikipedia.org/wiki/Statistical_mach...         1702
# 121   https://en.wikipedia.org/wiki/Artificial_neura...         1702
# 151   https://en.wikipedia.org/wiki/R_(programming_l...         1702
# ...                                                 ...          ...
# 4096      https://en.wikipedia.org/wiki/Fuzzy_computing         1702
# 4163      https://en.wikipedia.org/wiki/Graph_embedding         1702
# 4335           https://en.wikipedia.org/wiki/E-learning         1702
# 4444             https://en.wikipedia.org/wiki/Big_data         1702
# 4484  https://en.wikipedia.org/wiki/Knowledge_repres...         1702
#
#                 subfield_name  field_id        field_name  domain_id  \
# 1     Artificial Intelligence        17  Computer Science          3
# 37    Artificial Intelligence        17  Computer Science          3
# 88    Artificial Intelligence        17  Computer Science          3
# 121   Artificial Intelligence        17  Computer Science          3
# 151   Artificial Intelligence        17  Computer Science          3
# ...                       ...       ...               ...        ...
# 4096  Artificial Intelligence        17  Computer Science          3
# 4163  Artificial Intelligence        17  Computer Science          3
# 4335  Artificial Intelligence        17  Computer Science          3
# 4444  Artificial Intelligence        17  Computer Science          3
# 4484  Artificial Intelligence        17  Computer Science          3
#
#             domain_name                                        sibling_ids  \
# 1     Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# 37    Physical Sciences  T13674_T12380_T10951_T11010_T14175_T12611_T101...
# 88    Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# 121   Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# 151   Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# ...                 ...                                                ...
# 4096  Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# 4163  Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# 4335  Physical Sciences  T13674_T12380_T10951_T11010_T13650_T12611_T101...
# 4444  Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
# 4484  Physical Sciences  T13674_T12380_T10951_T11010_T13650_T14175_T126...
#
#       works_count  cited_by_count
# 1         3952624         1640349
# 37         409306          622443
# 88         283826         2999722
# 121        247207         4351608
# 151        224954          568812
# ...           ...             ...
# 4096        14815           66482
# 4163        13107           24789
# 4335         7863           33271
# 4444         4110            7024
# 4484         2572            6772
#
# [77 rows x 14 columns]

# %% [markdown]
# ## Works by topic

# %% [markdown]
# ### Check all topics present

# %%
topics_df = read_parquet("data/topics/topics.parquet")
# Out:
# Reading 'topics' from 'data/topics/topics.parquet' using engine='pyarrow'
# Read 4,516 rows from 'topics' in 0.02 sec.
# Converting dtypes took 0.00 sec. Size before: 0.01GB, after: 0.01GB
#   topic_id                              display_name  \
# 0   T10346      Magnetic confinement fusion research
# 1   T12157         Geochemistry and Geologic Mapping
# 2   T10451  Mycorrhizal Fungi and Plant Interactions
#
#                                          description  \
# 0  This cluster of papers covers a wide range of ...
# 1  This cluster of papers focuses on the applicat...
# 2  This cluster of papers explores the diverse in...
#
#                                             keywords  \
# 0  Turbulence_Tokamak_Transport_MHD Stability_Edg...
# 1  Machine Learning_Mineral Prospectivity_Remote ...
# 2  Mycorrhizal Fungi_Fungal Diversity_Plant Inter...
#
#                                            wikipedia  subfield_id  \
# 0       https://en.wikipedia.org/wiki/Plasma_physics         3106
# 1  https://en.wikipedia.org/wiki/Mineral_prospecting         1702
# 2           https://en.wikipedia.org/wiki/Mycorrhiza         1110
#
#                      subfield_name  field_id  \
# 0  Nuclear and High Energy Physics        31
# 1          Artificial Intelligence        17
# 2                    Plant Science        11
#
#                              field_name  domain_id        domain_name  \
# 0                 Physics and Astronomy          3  Physical Sciences
# 1                      Computer Science          3  Physical Sciences
# 2  Agricultural and Biological Sciences          1      Life Sciences
#
#                                          sibling_ids  works_count  \
# 0  T10025_T10384_T11044_T13458_T10921_T10093_T100...      9270869
# 1  T13674_T12380_T10951_T11010_T13650_T14175_T126...      3952624
# 2  T12253_T11796_T11578_T13422_T11613_T12657_T106...      3202968
#
#    cited_by_count
# 0         2538117
# 1         1640349
# 2         1949520

# %%
csv_folder = "data/works_by_topic_csv/"
files = os.listdir(csv_folder)

# %%
len(files)
# Out:
# 4516

# %%
topics_in_folder = [file[:-4] for file in files]

# %%
topics_in_df = topics_df.topic_id.to_list()

# %%
topics_in_folder_not_in_df = [topic for topic in topics_in_folder if topic not in topics_in_df]
topics_in_df_not_in_folder = [topic for topic in topics_in_df if topic not in topics_in_folder]
len(topics_in_folder_not_in_df), len(topics_in_df_not_in_folder)
# Out:
# (0, 0)

# %% [markdown]
# ### Transform to parquet

# %%
csv_folder = "data/works_by_topic_csv/"
parquet_folder = "data/works_by_topic_parquet/"

# %%
topics = [topic[:-4] for topic in os.listdir(csv_folder)]
len(topics)
# Out:
# 4516

# %%
for topic in tqdm(topics):
    csv_file_path = csv_folder + topic + ".csv"
    parquet_file_path = parquet_folder + topic + ".parquet"
    convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = ["date", "id", ], separator = ',', do_peek = False, do_print = False)
# Out:
#   0%|          | 0/4516 [00:00<?, ?it/s]

# %%
topic = topics[0]
parquet_file_path = parquet_folder + topic + ".parquet"
peek_parquet(parquet_file_path)
# Out:
# Name: 'T13871'
# Path: 'data/works_by_topic_parquet/T13871.parquet'
# Files: 1
# Rows: 5,623
# Schema:
#     id: large_string
#     date: large_string
#     type: large_string
#     language: large_string
#     journal: large_string
#     doi: large_string
#     authors: large_string
#     topics: large_string
#     references: large_string
#     sdg: large_string
#     keywords: large_string
#     awards: large_string
#     primary_topic: large_string
#     related_works: large_string
# 5 random rows:
#             id        date          type language      journal  \
# 0  W7126411087  2026-01-29       article           S5407051178
# 1  W7125952890  2026-01-28       article       en  S2765077160
# 2  W7115807244  2026-01-19  dissertation       en  S4306402616
# 3  W7124706820  2026-01-17       article       en  S2737566431
# 4  W7124573560  2026-01-17       article       en    S87018847
#
#                                doi  \
# 0  10.63363/aijfr.2026.v07i01.3147
# 1       10.1016/j.jics.2026.102451
# 2
# 3           10.3390/antiox15010122
# 4       10.1007/s00204-025-04289-5
#
#                                              authors  \
# 0       A5124672088__T;A5124652656__F;A5124485050__F
# 1  A5100700062_I303593345_F;A5069329739_I30359334...
# 2                            Kourkopoulos, Thanos__T
# 3  A5016617714_I102064193_T;A5085248982_I10206419...
# 4  A5123279779_I4210109381_F;A5077061484_I4210109...
#
#                                       topics  \
# 0  T13871_0.3333;T12302_0.1083;T10180_0.1036
# 1  T13871_0.9644;T13325_0.0064;T11393_0.0059
# 2  T13871_0.1439;T10686_0.1415;T12388_0.1083
# 3    T13871_0.99;T10116_0.0025;T11107_0.0008
# 4  T13871_0.9977;T13325_0.0002;T12302_0.0001
#
#                                           references                    sdg  \
# 0
# 1  W226416011;W1562902293;W1973730610;W1979083021...  2_0.41488516330718994
# 2                                                      2_0.7618747353553772
# 3  W1520897616;W1527262979;W1529168908;W187018469...
# 4  W1556817153;W1605332309;W1965634284;W196979691...
#
#                                             keywords awards primary_topic  \
# 0  Nanoparticle_0.626;Sensitivity (control system...               T13871
# 1  Melamine_0.9064;Silver nanoparticle_0.8041;Cop...               T13871
# 2  Hazardous waste_0.8117;Prioritization_0.7344;I...               T13871
# 3  Capacitation_0.8387;Sperm_0.7311;Oxidative str...               T13871
# 4  Synaptic plasticity_0.7328;Morris water naviga...               T13871
#
#   related_works
# 0
# 1
# 2
# 3
# 4

# %%
parquet_file_path = parquet_folder + topic + ".parquet"
df = read_parquet(parquet_file_path)
# Out:
# Reading 'T13871' from 'data/works_by_topic_parquet/T13871.parquet' using engine='pyarrow'
# Read 5,623 rows from 'T13871' in 0.02 sec.
# Converting dtypes took 0.08 sec. Size before: 0.00GB, after: 0.00GB
#             id        date          type language      journal  \
# 0  W7126411087  2026-01-29       article           S5407051178
# 1  W7125952890  2026-01-28       article       en  S2765077160
# 2  W7115807244  2026-01-19  dissertation       en  S4306402616
#
#                                doi  \
# 0  10.63363/aijfr.2026.v07i01.3147
# 1       10.1016/j.jics.2026.102451
# 2
#
#                                              authors  \
# 0       A5124672088__T;A5124652656__F;A5124485050__F
# 1  A5100700062_I303593345_F;A5069329739_I30359334...
# 2                            Kourkopoulos, Thanos__T
#
#                                       topics  \
# 0  T13871_0.3333;T12302_0.1083;T10180_0.1036
# 1  T13871_0.9644;T13325_0.0064;T11393_0.0059
# 2  T13871_0.1439;T10686_0.1415;T12388_0.1083
#
#                                           references                    sdg  \
# 0
# 1  W226416011;W1562902293;W1973730610;W1979083021...  2_0.41488516330718994
# 2                                                      2_0.7618747353553772
#
#                                             keywords awards primary_topic  \
# 0  Nanoparticle_0.626;Sensitivity (control system...               T13871
# 1  Melamine_0.9064;Silver nanoparticle_0.8041;Cop...               T13871
# 2  Hazardous waste_0.8117;Prioritization_0.7344;I...               T13871
#
#   related_works
# 0
# 1
# 2

# %%
df.awards.apply(lambda x : len(x)).value_counts()
# Out:
# awards
# 0      5255
# 23      162
# 47       77
# 71       27
# 22       23
# 46       17
# 95        8
# 94        7
# 70        7
# 119       5
# 142       4
# 69        4
# 117       4
# 118       3
# 93        3
# 166       3
# 143       2
# 236       1
# 141       1
# 191       1
# 238       1
# 92        1
# 167       1
# 45        1
# 164       1
# 165       1
# 212       1
# 189       1
# 91        1
# Name: count, dtype: int64

# %%
parquet_folder = "data/works2citations_by_topic_parquet/"
parquet_file_path = parquet_folder + topic + ".parquet"
citations_df = read_parquet(parquet_file_path)
# Out:
# Reading 'T14028' from 'data/works2citations_by_topic_parquet/T14028.parquet' using engine='pyarrow'
# Read 213,531 rows from 'T14028' in 0.09 sec.
# Converting dtypes took 0.00 sec. Size before: 0.02GB, after: 0.02GB
#        work_id primary_topic publication_date referenced_work_id  \
# 0  W4412028003        T11177       2025-07-04        W3179432328
# 1  W4403431318        T11177       2024-10-15          W27222542
# 2  W4392854270        T11177       2024-03-15        W1971556202
#
#   referenced_primary_topic referenced_publication_date
# 0                   T14028                  2021-07-13
# 1                   T14028                  1996-01-01
# 2                   T14028                  1994-10-16

# %%
citation_counts = citations_df.groupby("referenced_work_id").size().reset_index(name="cited_by_count")
citation_counts
# Out:
#       referenced_work_id  cited_by_count
# 0            W1000874774               1
# 1            W1001958261               3
# 2             W100421077              23
# 3            W1006562173               1
# 4            W1007648502               1
# ...                  ...             ...
# 21284         W994834425               3
# 21285          W99668335               1
# 21286         W998146579               1
# 21287         W999339260              38
# 21288          W99940997               9
#
# [21289 rows x 2 columns]

# %%
df
# Out:
#                 id        date          type language      journal  \
# 0      W7125826661  2026-01-27       article       en  S4210234263
# 1      W7125814211  2026-01-27       article       en   S205866209
# 2      W7125385546  2026-01-22       article       en   S127393932
# 3      W7125816570  2026-01-21       article       en  S4210174320
# 4      W7124896153  2026-01-18       article       en   S149937609
# ...            ...         ...           ...      ...          ...
# 76921  W6903235804  1753-01-01       article       en  S4306400572
# 76922  W7037216328  1736-01-01       article       en
# 76923  W2496461194  1651-01-01  book-chapter       en  S4306463708
# 76924  W7037026684  1560-01-01       article       en
# 76925  W7027860198  1512-01-01       article       la
#
#                                      doi authors  \
# 0            10.21608/eajbse.2026.480905
# 1                      10.1159/000550719
# 2             10.1007/s10753-025-02444-9
# 3      10.21608/ejchem.2026.436382.12534
# 4              10.1016/j.cej.2026.173056
# ...                                  ...     ...
# 76921  10.1021/acs.jmedchem.0c02237.s002
# 76922
# 76923     10.1093/oseo/instance.00011369
# 76924
# 76925
#
#                                           topics  \
# 0       T14028_0.9744;T11386_0.0054;T12750_0.001
# 1      T14028_0.9366;T10634_0.0445;T11353_0.0022
# 2      T14028_0.7949;T11103_0.0408;T11386_0.0156
# 3      T14028_0.4668;T11386_0.1703;T10702_0.0878
# 4      T14028_0.3546;T12689_0.0759;T11966_0.0645
# ...                                          ...
# 76921  T14028_0.2024;T11353_0.1372;T12477_0.1051
# 76922  T14028_0.2063;T11353_0.1424;T12388_0.1042
# 76923                              T14028_0.2156
# 76924  T14028_0.3924;T11103_0.1501;T11353_0.1348
# 76925   T14028_0.294;T11641_0.2595;T11386_0.0345
#
#                                               references sdg  \
# 0
# 1
# 2      W135218290;W1992450378;W2057443193;W2061473393...
# 3
# 4      W1480260780;W2030141189;W2110341717;W214732948...
# ...                                                  ...  ..
# 76921
# 76922
# 76923
# 76924
# 76925
#
#                                                 keywords grants primary_topic
# 0      Pathogenic bacteria_0.8014;Antibacterial activ...               T14028
# 1      Sensitization_0.8468;Venom_0.7916;Immunotherap...               T14028
# 2      Oxidative stress_0.6667;Nitric oxide_0.6094;Gl...               T14028
# 3      Seasonality_0.7431;Variation (astronomy)_0.364...               T14028
# 4      Melittin_0.8755;Breast cancer_0.6223;Chitosan_...               T14028
# ...                                                  ...    ...           ...
# 76921  Cytotoxicity_0.7601;Oncolytic virus_0.7316;Mel...               T14028
# 76922  Power (physics)_0.2283;Identity (music)_0.207;...               T14028
# 76923                   Environmental science_0.28023863               T14028
# 76924  Field (mathematics)_0.3673;Order (exchange)_0....               T14028
# 76925  Set (abstract data type)_0.2283;Relation (data...               T14028
#
# [76926 rows x 13 columns]

# %%
works_parquet_folder = "data/works_by_topic_parquet/"
works_parquet_folder2 = "data/works_by_topic_parquet2/"
os.makedirs(works_parquet_folder2, exist_ok = True)
citations_parquet_folder = "data/works2citations_by_topic_parquet/"
references_parquet_folder = "data/works2references_by_topic_parquet/"

for topic in tqdm(topics):
    # --- load works for this topic ---
    works_path = os.path.join(works_parquet_folder, f"{topic}.parquet")
    works_df = pd.read_parquet(works_path)

    # --- load citations for this topic ---
    citations_path = os.path.join(citations_parquet_folder, f"{topic}.parquet")
    citations_df = pd.read_parquet(citations_path)

    # --- load references for this topic ---
    references_path = os.path.join(references_parquet_folder, f"{topic}.parquet")
    references_df = pd.read_parquet(references_path)

    # =========================
    # 1. CITATIONS RECEIVED
    # count rows per referenced_work_id
    # =========================
    citation_counts = (
        citations_df.groupby("referenced_work_id")
        .size()
        .reset_index(name="cited_by_count_computed")
    )

    works_df = works_df.merge(
        citation_counts,
        left_on="id",
        right_on="referenced_work_id",
        how="left"
    ).drop(columns=["referenced_work_id"])

    works_df["cited_by_count_computed"] = (
        works_df["cited_by_count_computed"].fillna(0).astype("int64")
    )

    # =========================
    # 2. REFERENCES MADE
    # count rows per work_id
    # =========================
    reference_counts = (
        references_df.groupby("work_id")
        .size()
        .reset_index(name="references_count_computed")
    )

    works_df = works_df.merge(
        reference_counts,
        left_on="id",
        right_on="work_id",
        how="left"
    ).drop(columns=["work_id"])

    works_df["references_count_computed"] = (
        works_df["references_count_computed"].fillna(0).astype("int64")
    )

    # (optional) save back
    out_path = os.path.join(works_parquet_folder2, f"{topic}.parquet")
    works_df.to_parquet(out_path, index=False)
# Out:
#   0%|          | 0/4516 [00:00<?, ?it/s]

# %%
for topic in ai_topics:
    
    columns = ["id", "date", "type", "language", "doi", "topics", "keywords", "cited_by_count_computed"]

# %%
works_df.sort_values("cited_by_count_computed")
# Out:
#                id        date          type language      journal  \
# 2310  W7097069474  2014-01-22       article       en
# 2257  W1528778344  2014-05-12  dissertation       en
# 2275  W2072779915  2014-03-30       article       en  S4210178289
# 2276  W3143150319  2014-03-25       article       en  S2764679879
# 2280  W4214543131  2014-03-15       article       en  S4210199966
# ...           ...         ...           ...      ...          ...
# 4289  W2168505600  2008-08-09       article       en   S186282544
# 4407  W2120530839  2007-09-01       article       en   S206734468
# 3910  W1985043634  2009-06-18       article       en   S111155417
# 4454  W1601956008  2007-01-01          book       en
# 5102  W2166439728  1973-07-20       article       en     S3880285
#
#                                   doi authors  \
# 2310
# 2257
# 2275      10.13103/jfhs.2014.29.1.021
# 2276  10.7506/spkx1002-6630-201406037
# 2280        10.1007/s00240-014-0648-1
# ...                               ...     ...
# 4289            10.1093/toxsci/kfn160
# 4407       10.1177/104063870701900510
# 3910                10.1021/ja9037017
# 4454          10.1016/c2016-0-01687-x
# 5102     10.1126/science.181.4096.230
#
#                                          topics  \
# 2310  T13871_0.1426;T10875_0.0898;T13325_0.0527
# 2257      T13871_1.0;T10819_0.9841;T13325_0.968
# 2275  T13871_0.9989;T13325_0.9948;T10180_0.9671
# 2276   T13871_0.9992;T13325_0.9182;T12302_0.905
# 2280                              T13871_0.9946
# ...                                         ...
# 4289  T13871_0.9999;T10819_0.9819;T12388_0.9116
# 4407  T13871_0.9998;T12388_0.9805;T10800_0.9779
# 3910  T13871_0.9999;T12388_0.9914;T10819_0.9878
# 4454                              T13871_0.6736
# 5102                T13871_0.4623;T13540_0.4143
#
#                                              references sdg  \
# 2310
# 2257  W113515681;W1489571934;W1765688430;W1966156295...
# 2275  W1973602973;W2052894441;W2075066186;W213161989...
# 2276
# 2280
# ...                                                 ...  ..
# 4289  W44356197;W1499772973;W1564619006;W1755391355;...
# 4407  W17199429;W1597429012;W1969028305;W2006440916;...
# 3910  W1489710234;W1988214044;W1997380582;W201915723...
# 4454
# 5102  W854912779;W1983688764;W1990150186;W2049382856...
#
#                                                keywords grants primary_topic  \
# 2310                     Scope (computer science)_0.539               T13871
# 2257  High-performance liquid chromatography_0.83484...               T13871
# 2275  Formaldehyde_0.9158947;Phenol_0.84947884;Chemi...               T13871
# 2276  Melamine_0.86162937;Chromatography_0.6294806;H...               T13871
# 2280  Melamine_0.9099543;Composition (language)_0.62...               T13871
# ...                                                 ...    ...           ...
# 4289  Cyanuric acid_0.9853083;Melamine_0.9117625;Che...               T13871
# 4407  Azotemia_0.8790613;Lethargy_0.76694936;Outbrea...               T13871
# 3910  Melamine_0.98524386;Chemistry_0.90361035;Cyanu...               T13871
# 4454  Veterinary Drugs_0.52392966;Clinical toxicolog...               T13871
# 5102  Methylmercury_0.7264561;Poison control_0.41752...               T13871
#
#       cited_by_count_computed  references_count_computed
# 2310                        0                          0
# 2257                        0                         47
# 2275                        0                          5
# 2276                        0                          0
# 2280                        0                          0
# ...                       ...                        ...
# 4289                      449                         14
# 4407                      518                         10
# 3910                      588                         11
# 4454                      660                          0
# 5102                     1576                          7
#
# [5610 rows x 15 columns]

# %%
print(df.authors.apply(lambda x : len(x)).value_counts())
# Out:
# authors
# 0    76926
# Name: count, dtype: int64

# %%
print(df.keywords.apply(lambda x : len(x)).value_counts())
# Out:
# keywords
# 27     785
# 19     730
# 18     554
# 0      434
# 20     367
#       ...
# 721      1
# 15       1
# 531      1
# 617      1
# 620      1
# Name: count, Length: 596, dtype: int64

# %% [markdown]
# ## Works2text by topic

# %%
csv_folder = "data/works2text_by_topic_csv/"
parquet_folder = "data/works2text_by_topic_parquet/"

# %%
topics = [topic[:-4] for topic in os.listdir(csv_folder)]
len(topics)
# Out:
# 4516

# %%
for topic in tqdm(topics):
    csv_file_path = csv_folder + topic + ".csv"
    parquet_file_path = parquet_folder + topic + ".parquet"
    convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = ["date", "id", ], separator = ';', do_peek = False, do_print = False)
# Out:
#   0%|          | 0/4516 [00:00<?, ?it/s]

# %%
peek_parquet(parquet_file_path)
# Out:
# Name: 'T14028'
# Path: 'data/works2text_by_topic_parquet/T14028.parquet'
# Files: 1
# Rows: 76,926
# Schema:
#     id: large_string
#     date: large_string
#     title: large_string
#     abstract: large_string
# 5 random rows:
#             id        date                                              title  \
# 0  W7125826661  2026-01-27  Antibacterial Activity of Chitosan Nanoparticl...
# 1  W7125814211  2026-01-27  The Clinical Importance of Component Based Dia...
# 2  W7125385546  2026-01-22  A Melittin-Derived Lead Compound Ameliorates S...
# 3  W7125816570  2026-01-21  Biochemical Effects of Seasonal Variation and ...
# 4  W7124896153  2026-01-18  Melittin nanoparticle-based bidirectional spra...
#
#                                             abstract
# 0
# 1  Introduction Venom immunotherapy (VIT) is the ...
# 2  Abstract Severe acute pancreatitis (SAP) is a ...
# 3
# 4

# %% [markdown]
# ## Works2citations by topic

# %%
csv_folder = "data/works2citations_by_topic_csv/"
parquet_folder = "data/works2citations_by_topic_parquet/"

# %%
topics = [topic[:-4] for topic in os.listdir(csv_folder)]
len(topics)
# Out:
# 4516

# %%
for topic in tqdm(topics):
    csv_file_path = csv_folder + topic + ".csv"
    parquet_file_path = parquet_folder + topic + ".parquet"
    convert_csv2parquet(csv_file_path, parquet_file_path, sort_by = None, separator = ',', do_peek = False, do_print = False)
# Out:
#   0%|          | 0/4516 [00:00<?, ?it/s]

# %%
peek_parquet(parquet_file_path)
# Out:
# Name: 'T14028'
# Path: 'data/works2citations_by_topic_parquet/T14028.parquet'
# Files: 1
# Rows: 213,531
# Schema:
#     work_id: large_string
#     primary_topic: large_string
#     publication_date: large_string
#     referenced_work_id: large_string
#     referenced_primary_topic: large_string
#     referenced_publication_date: large_string
# 5 random rows:
#        work_id primary_topic publication_date referenced_work_id  \
# 0  W4412028003        T11177       2025-07-04        W3179432328
# 1  W4403431318        T11177       2024-10-15          W27222542
# 2  W4392854270        T11177       2024-03-15        W1971556202
# 3  W4212810480        T11177       2022-02-17        W1971556202
# 4  W3128463426        T11177       2021-02-12        W2048172946
#
#   referenced_primary_topic referenced_publication_date
# 0                   T14028                  2021-07-13
# 1                   T14028                  1996-01-01
# 2                   T14028                  1994-10-16
# 3                   T14028                  1994-10-16
# 4                   T14028                  1997-04-01

# %% [markdown]
# # Peek other files

# %% [markdown]
# ## all_works2primary_topic

# %%
peek_parquet("data/all_works2primary_topic_parquet/all_works2primary_topic.parquet")
# Out:
# Name: 'all_works2primary_topic'
# Path: 'data/all_works2primary_topic_parquet/all_works2primary_topic.parquet'
# Files: 1
# Rows: 306,133,392
# Schema:
#     id: large_string
#     date: large_string
#     primary_topic: large_string
#     -- schema metadata --
#     pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 602
# 5 random rows:
#             id        date primary_topic
# 0  W7126435799  2026-02-01        T14064
# 1  W7126372280  2026-02-01        T14064
# 2  W7126447841  2026-01-31        T14064
# 3  W7126389308  2026-01-31        T14064
# 4  W7126248061  2026-01-30        T14064

# %%
all_works2primary_topic_df = read_parquet("data/all_works2primary_topic_parquet/all_works2primary_topic.parquet")
# Out:
# Reading 'all_works2primary_topic' from 'data/all_works2primary_topic_parquet/all_works2primary_topic.parquet' using engine='pyarrow'
# Read 210,864,615 rows from 'all_works2primary_topic' in 10.52 sec.
# Converting dtypes took 0.14 sec. Size before: 10.00GB, after: 10.00GB
#             id        date primary_topic
# 0  W4410793892  2025-05-28        T14064
# 1  W4410791727  2025-05-27        T14064
# 2  W4410789294  2025-05-27        T14064

# %%
all_works2primary_topic_df.primary_topic.nunique()
# Out:
# 4516

# %%
all_works2primary_topic_df.date.min(), all_works2primary_topic_df.date.max()
# Out:
# ('0004-07-12', '2025-12-31')

# %%
all_works2primary_topic_df.date.apply(lambda x : x if x > "1" else None).min()
# Out:
# '1007-04-01'

# %% [markdown]
# ## Topics

# %%
parquet_file_path = "data/topics/topics.parquet"
topics_df = read_parquet(parquet_file_path)
# Out:
# Reading 'topics' from 'data/topics/topics.parquet' using engine='pyarrow'
# Read 4,516 rows from 'topics' in 0.03 sec.
# Converting dtypes took 0.00 sec. Size before: 0.01GB, after: 0.01GB
#   topic_id                              display_name  \
# 0   T11881    Crystallization and Solubility Studies
# 1   T11475           French Urban and Social Studies
# 2   T13445  American Constitutional Law and Politics
#
#                                          description  \
# 0  This cluster of papers focuses on the crystall...
# 1  This cluster of papers explores the intersecti...
# 2  This cluster of papers explores the developmen...
#
#                                             keywords  \
# 0  Crystallization_Nucleation_Solubility_Polymorp...
# 1  Territorial Governance_Environmental Participa...
# 2  American founding_Constitutional government_Re...
#
#                                            wikipedia  subfield_id  \
# 0      https://en.wikipedia.org/wiki/Crystallization         2505
# 1  https://en.wikipedia.org/wiki/Territorial_gove...         3312
# 2  https://en.wikipedia.org/wiki/American_politic...         3320
#
#                                    subfield_name  field_id         field_name  \
# 0                            Materials Chemistry        25  Materials Science
# 1                Sociology and Political Science        33    Social Sciences
# 2  Political Science and International Relations        33    Social Sciences
#
#    domain_id        domain_name  \
# 0          3  Physical Sciences
# 1          2    Social Sciences
# 2          2    Social Sciences
#
#                                          sibling_ids  works_count  \
# 0  T10275_T13889_T12302_T10440_T10311_T12340_T114...       975044
# 1  T10927_T13843_T13162_T12635_T13428_T12432_T112...       652021
# 2  T14181_T12986_T13504_T13643_T12956_T13057_T138...       465559
#
#    cited_by_count
# 0          784318
# 1          699274
# 2         1814934

# %%
topics_df[topics_df.subfield_name.apply(lambda x : "artificial" in x.lower())]
# Out:
#      topic_id                                       display_name  \
# 29     T10181             Natural Language Processing Techniques
# 54     T10320                   Neural Networks and Applications
# 80     T13734  Advanced Computational Techniques and Applicat...
# 98     T12157                  Geochemistry and Geologic Mapping
# 125    T10215                        Semantic Web and Ontologies
# ...       ...                                                ...
# 4303   T14175          Intuitionistic Fuzzy Systems Applications
# 4347   T13567                     AI and Multimedia in Education
# 4371   T13904               Artificial Intelligence Applications
# 4393   T13898         Diverse Interdisciplinary Research Studies
# 4420   T13514              Experience-Based Knowledge Management
#
#                                             description  \
# 29    This cluster of papers focuses on statistical ...
# 54    This cluster of papers covers a wide range of ...
# 80    This cluster of papers covers a wide range of ...
# 98    This cluster of papers focuses on the applicat...
# 125   This cluster of papers focuses on the Semantic...
# ...                                                 ...
# 4303  This cluster of papers focuses on enhancing e-...
# 4347  This cluster of papers focuses on the optimiza...
# 4371  This cluster of papers covers a wide range of ...
# 4393  This cluster of papers covers a wide range of ...
# 4420  This cluster of papers focuses on experience-b...
#
#                                                keywords  \
# 29    Statistical Machine Translation_Neural Machine...
# 54    Neural Networks_Self-Organizing Maps_Backpropa...
# 80    Expert Systems_Wavelet Analysis_Machine Learni...
# 98    Machine Learning_Mineral Prospectivity_Remote ...
# 125   Semantic Web_Ontology_Linked Data_RDF_OWL_Sche...
# ...                                                 ...
# 4303  Intelligent Agent_E-Learning_InterCriteria Ana...
# 4347  Big Data Scheduling_Fractal Encoding_Visual Tr...
# 4371  Artificial Intelligence_Neural Networks_Deep L...
# 4393  Cybernetics_Information Theory_Risk Management...
# 4420  Decisional DNA_Set of Experience Knowledge Str...
#
#                                               wikipedia  subfield_id  \
# 29    https://en.wikipedia.org/wiki/Statistical_mach...         1702
# 54    https://en.wikipedia.org/wiki/Artificial_neura...         1702
# 80    https://en.wikipedia.org/wiki/Artificial_intel...         1702
# 98    https://en.wikipedia.org/wiki/Mineral_prospecting         1702
# 125          https://en.wikipedia.org/wiki/Semantic_Web         1702
# ...                                                 ...          ...
# 4303           https://en.wikipedia.org/wiki/E-learning         1702
# 4347             https://en.wikipedia.org/wiki/Big_data         1702
# 4371  https://en.wikipedia.org/wiki/Artificial_intel...         1702
# 4393          https://en.wikipedia.org/wiki/Cybernetics         1702
# 4420  https://en.wikipedia.org/wiki/Knowledge_repres...         1702
#
#                 subfield_name  field_id        field_name  domain_id  \
# 29    Artificial Intelligence        17  Computer Science          3
# 54    Artificial Intelligence        17  Computer Science          3
# 80    Artificial Intelligence        17  Computer Science          3
# 98    Artificial Intelligence        17  Computer Science          3
# 125   Artificial Intelligence        17  Computer Science          3
# ...                       ...       ...               ...        ...
# 4303  Artificial Intelligence        17  Computer Science          3
# 4347  Artificial Intelligence        17  Computer Science          3
# 4371  Artificial Intelligence        17  Computer Science          3
# 4393  Artificial Intelligence        17  Computer Science          3
# 4420  Artificial Intelligence        17  Computer Science          3
#
#             domain_name                                        sibling_ids  \
# 29    Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 54    Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 80    Physical Sciences  T10637_T11273_T10639_T14413_T13083_T11689_T135...
# 98    Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 125   Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# ...                 ...                                                ...
# 4303  Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 4347  Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 4371  Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 4393  Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
# 4420  Physical Sciences  T10637_T13734_T11273_T10639_T14413_T13083_T116...
#
#       works_count  cited_by_count
# 29         233196         3194394
# 54         205089         4257999
# 80         179068          192945
# 98         164104         1500551
# 125        154257         1470833
# ...           ...             ...
# 4303         3213           31320
# 4347         2569            5596
# 4371         2175            4082
# 4393         1710           16600
# 4420         1251            5971
#
# [77 rows x 14 columns]
