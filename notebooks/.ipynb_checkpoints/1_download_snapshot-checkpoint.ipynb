# %%
import os
os.chdir("../") # resets notebook directory to repository root folder (DO ONLY ONCE!)
import time
import urllib.request
import xml.etree.ElementTree as ET

BASE_URL = "https://openalex.s3.amazonaws.com"
DOWNLOAD_DIR = "data/openalex-snapshot"
NS = {"s3": "http://s3.amazonaws.com/doc/2006-03-01/"}

def list_files(prefix):
    files = []
    marker = ""
    while True:
        url = f"{BASE_URL}/?prefix={prefix}&marker={marker}"
        with urllib.request.urlopen(url) as response:
            xml = response.read()
        root = ET.fromstring(xml)
        for contents in root.findall(".//s3:Contents", namespaces=NS):
            key = contents.find("s3:Key", namespaces=NS).text
            if key.endswith(".gz") or key.endswith(".txt"):
                files.append(key)
        is_truncated = root.find("s3:IsTruncated", namespaces=NS)
        if is_truncated is not None and is_truncated.text == "true":
            marker = files[-1]
        else:
            break
    return files

def download_file(key):
    dest_path = os.path.join(DOWNLOAD_DIR, key)
    if os.path.exists(dest_path):
        print(f"✔ Already downloaded: {key}")
        return
    os.makedirs(os.path.dirname(dest_path), exist_ok=True)
    url = f"{BASE_URL}/{key}"
    print(f"↓ Downloading {key}")
    try:
        urllib.request.urlretrieve(url, dest_path)
        time.sleep(0.5)
    except Exception as e:
        print(f"⚠ Failed to download {key}: {e}")

def main():
    print("🔍 Listing files in the datadump")
    files = list_files("")
    print(f"Found {len(files)} files")

    for file_key in files:
        download_file(file_key)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Listing files in the datadump
# Found 2558 files
# ✔ Already downloaded: LICENSE.txt
# ✔ Already downloaded: README.txt
# ✔ Already downloaded: RELEASE_NOTES.txt
# ✔ Already downloaded: data/authors/updated_date=2023-06-08/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-13/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-14/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-18/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-22/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-26/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-27/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-28/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-06-30/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-07-02/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-07-06/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-07-14/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-07-17/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-07-20/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-07-21/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-11-01/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-11-07/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-11-08/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2023-11-09/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-02/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-03/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-05/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-06/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-07/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-08/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-09/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-10/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-11/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-12/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-13/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-14/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-15/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-16/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-17/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-18/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-19/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-20/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-21/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-22/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-23/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-24/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-25/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-26/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-27/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-28/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-29/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-30/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-05-31/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-01/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-02/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-03/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-04/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-05/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-06/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-07/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-08/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-09/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-10/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-11/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-12/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-13/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-14/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-15/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-16/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-17/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-18/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-19/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-20/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-21/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-22/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-23/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-24/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-25/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-26/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-27/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-28/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-29/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-06-30/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-01/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-02/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-03/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-04/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-05/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-06/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-07/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-08/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-09/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-10/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-11/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-12/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-13/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-14/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-15/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-16/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-17/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-18/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-19/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-20/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-21/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-22/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-23/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-24/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-25/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-26/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-27/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-28/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-29/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-30/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-07-31/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-01/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-02/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-03/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-04/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-05/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-06/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-07/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-08/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-09/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-10/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-11/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-12/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-13/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-14/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-15/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-16/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-17/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-18/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-19/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-20/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-21/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-22/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-23/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-24/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-25/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-26/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-27/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-28/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-29/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-30/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-08-31/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-09-01/part_000.gz
# ✔ Already downloaded: data/authors/updated_date=2024-09