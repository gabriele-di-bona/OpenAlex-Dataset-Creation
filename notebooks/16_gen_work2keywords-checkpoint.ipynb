# %%
import os
os.chdir("../") # resets notebook directory to repository root folder (DO ONLY ONCE!)
import polars as pl
import pandas as pd
import pyarrow.parquet as pypq
import textwrap
from pathlib import Path
import time

from tqdm.auto import tqdm
tqdm.pandas()

# %%
import sys
# Add utils directory in the list of directories to look for packages to import
sys.path.insert(0, os.path.join(os.getcwd(),'utils'))
from read_parquet import *
# Out:
# Using PyArrow strings!

# %%
works_by_topic_parquet_folder = "data/works_by_topic_parquet/"
works2keyword_by_topic_parquet_folder = "data/works2keyword_by_topic_parquet/"
os.makedirs(works2keyword_by_topic_parquet_folder, exist_ok=True)

# %%
topics = [topic[:-8] for topic in os.listdir(works_by_topic_parquet_folder)]

# %%
len(topics)
# Out:
# 4516

# %%
topic = topics[0]
works_df = read_parquet(works_by_topic_parquet_folder+topic, columns = ["id", "date", "keywords"])
# Out:
# Reading 'T14064' from 'data/works_by_topic_parquet/T14064.parquet' using engine='pyarrow'
# Read 36,130 rows from 'T14064' in 0.25 sec.
# Converting dtypes took 0.00 sec. Size before: 0.01GB, after: 0.01GB
#             id        date                                           keywords
# 0  W7126435799  2026-02-01  Tourism_0.6826;Diversity (politics)_0.6036;Sam...
# 1  W7126372280  2026-02-01  Parliament_0.8233;Social media_0.729;Politics_...
# 2  W7126447841  2026-01-31  Sustainability_0.7011;Organizational culture_0...

# %%
def get_keyword_scores(x):
    if not x or pd.isna(x):
        return []  # empty if missing
    parts = [i.split('_') for i in x.split(';')]
    return parts   # e.g. [['keyword1','0.9'], ['keyword2','0.8']]

def generate_keyword_score_df(parquet_file_path):
    # Read only needed columns
    works_df = read_parquet(parquet_file_path, columns=["id", "date", "keywords"], quiet=True)

    # Parse keyword into list of [keyword, score]
    works_df['keyword_list'] = works_df['keywords'].apply(get_keyword_scores)

    # Drop rows where list is empty
    works_df = works_df[works_df['keyword_list'].map(len) > 0]

    # Expand keyword_list into multiple rows
    works_df = works_df.explode('keyword_list')
    works_df = works_df.reset_index().rename(columns={'index': 'works_by_topic_index'})

    # Split keyword_list into two columns: keyword, score
    works_df[['keyword', 'score']] = pd.DataFrame(works_df['keyword_list'].tolist(), index=works_df.index)

    # Drop helper column
    works_df = works_df.drop(columns=['keywords', 'keyword_list'])

    # Convert score to float
    works_df['score'] = works_df['score'].astype(float)

    return works_df

def create_keyword_score_df(origin_works_parquet_file_path, destination_topic_parquet_file_path, compression='brotli', do_peek = True, do_print = True):
    works_df = generate_keyword_score_df(origin_works_parquet_file_path)
    works_df.to_parquet(destination_topic_parquet_file_path, compression=compression)
    if do_print:
        print(f"Successfully generated {destination_topic_parquet_file_path} using {origin_works_parquet_file_path}.")
    if do_peek:
        if do_print:
            print("Here's a peek.")
        peek_parquet(destination_topic_parquet_file_path)

# %%
for topic in tqdm(topics):
    origin_works_parquet_file_path = works_by_topic_parquet_folder+topic+".parquet"
    destination_topic_parquet_file_path = works2keyword_by_topic_parquet_folder+topic+".parquet"
    create_keyword_score_df(origin_works_parquet_file_path, destination_topic_parquet_file_path, do_peek = False, do_print = False)
# Out:
#   0%|          | 0/4516 [00:00<?, ?it/s]

# %%
peek_parquet(destination_topic_parquet_file_path)
# Out:
# Name: 'T10091'
# Path: 'data/works2keyword_by_topic_parquet/T10091.parquet'
# Files: 1
# Rows: 1,464,925
# Schema:
#     works_by_topic_index: int64
#     id: large_string
#     date: large_string
#     keyword: large_string
#     score: double
#     -- schema metadata --
#     pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 836
# 5 random rows:
#    works_by_topic_index           id        date           keyword   score
# 0                     0  W7083686573  2030-01-01     Transcriptome  0.5949
# 1                     0  W7083686573  2030-01-01  Follicular fluid  0.5554
# 2                     0  W7083686573  2030-01-01      Metabolomics  0.5463
# 3                     0  W7083686573  2030-01-01  Ovarian follicle  0.3566
# 4                     0  W7083686573  2030-01-01  Follicular phase  0.3345

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# assuming you already have: topics, works2topic_by_topic_parquet_folder
all_dfs = []

for topic in tqdm(topics):
    p = f"{works2keyword_by_topic_parquet_folder}{topic}.parquet"
    df = pd.read_parquet(p, columns=["keyword","score"])
    df = df.copy()
    all_dfs.append(df)

# merge everything
df_all = pd.concat(all_dfs, ignore_index=True)

# columns to plot
score_cols = ["score"]

bins = np.linspace(0, 1, 51)

plt.figure(figsize=(9, 5))

for i, c in enumerate(score_cols):
    scores = df_all[c].astype(float).clip(0, 1)
    plt.hist(
        scores,
        bins=bins,
        density=True,
        alpha=0.7,
        label=c
    )

# labels
plt.xlabel("Keyword classification score")
plt.ylabel("Density")
plt.title("Score distribution of keywords")
# plt.legend()

plt.tight_layout()
os.makedirs("figures", exist_ok = True)
plt.savefig("figures/all_keyword_scores_hist.png", dpi=300)
plt.savefig("figures/all_keyword_scores_hist.pdf")
plt.show()
# Out:
#   0%|          | 0/4516 [00:00<?, ?it/s]

# %%
for c in score_cols:
    scores = df_all[c].astype(float).clip(0, 1)
    total  = len(scores)
    print(f"total rows = {total:,}")
    print(f"average = {scores.mean()}")
    print(f"std = {scores.std()}")
# Out:
# total rows = 2,337,495,976
# average = 0.4328411113888726
# std = 0.2045273895632934
